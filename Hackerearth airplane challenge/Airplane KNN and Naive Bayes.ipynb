# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident/feature_1.csv")
df_test = pd.read_csv(r"E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident/feature_1_test.csv")

# %%
df_test.head()
# Out:
#    Accident_ID  Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0            1     19.497717                     16                        6
# 1           10     58.173516                     15                        3
# 2           14     33.287671                     15                        3
# 3           17      3.287671                     21                        5
# 4           21     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       72.151322               0.388959              78.32
# 1       64.585232               0.250841              78.60
# 2       64.721969               0.336669              86.96
# 3       66.362808               0.421775              80.86
# 4       56.107566               0.313228              79.22
#
#    Accident_Type_Code  Max_Elevation  Violations  ...  \
# 0                   4   37949.724386           2  ...
# 1                   7   30194.805567           2  ...
# 2                   6   17572.925484           1  ...
# 3                   3   40209.186341           2  ...
# 4                   2   35495.525408           2  ...
#
#    feature_Turbulence_In_gforces+Adverse_Weather_Metric  \
# 0                                           0.458651
# 1                                           0.253618
# 2                                           0.340985
# 3                                           0.621765
# 4                                           0.796924
#
#    feature_Cabin_Temperature-Max_Elevation  \
# 0                            -37871.404386
# 1                            -30116.205567
# 2                            -17485.965484
# 3                            -40128.326341
# 4                            -35416.305408
#
#    feature_Cabin_Temperature+Max_Elevation  \
# 0                             38028.044386
# 1                             30273.405567
# 2                             17659.885484
# 3                             40290.046341
# 4                             35574.745408
#
#    feature_Cabin_Temperature-Adverse_Weather_Metric  \
# 0                                         78.250308
# 1                                         78.597223
# 2                                         86.955684
# 3                                         80.660010
# 4                                         78.736304
#
#    feature_Cabin_Temperature+Adverse_Weather_Metric  \
# 0                                         78.389692
# 1                                         78.602777
# 2                                         86.964316
# 3                                         81.059990
# 4                                         79.703696
#
#    feature_Max_Elevation-Adverse_Weather_Metric  \
# 0                                  37949.654694
# 1                                  30194.802790
# 2                                  17572.921168
# 3                                  40208.986351
# 4                                  35495.041712
#
#    feature_Max_Elevation+Adverse_Weather_Metric  c_feat_1  c_feat_2  c_feat_3
# 0                                  37949.794079     False     False      True
# 1                                  30194.808345      True     False     False
# 2                                  17572.929800     False     False      True
# 3                                  40209.386332     False     False     False
# 4                                  35496.009103     False      True     False
#
# [5 rows x 134 columns]

# %%
y = df["Severity"]
df = df.drop("Severity",axis =1)

# %%
y = pd.DataFrame(y)

# %%
ID = df_test["Accident_ID"]
df_test = df_test.drop("Accident_ID",axis = 1)

# %%
df.shape
# Out:
# (10000, 133)

# %%
df_test.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0     19.497717                     16                        6
# 1     58.173516                     15                        3
# 2     33.287671                     15                        3
# 3      3.287671                     21                        5
# 4     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       72.151322               0.388959              78.32
# 1       64.585232               0.250841              78.60
# 2       64.721969               0.336669              86.96
# 3       66.362808               0.421775              80.86
# 4       56.107566               0.313228              79.22
#
#    Accident_Type_Code  Max_Elevation  Violations  Adverse_Weather_Metric  ...  \
# 0                   4   37949.724386           2                0.069692  ...
# 1                   7   30194.805567           2                0.002777  ...
# 2                   6   17572.925484           1                0.004316  ...
# 3                   3   40209.186341           2                0.199990  ...
# 4                   2   35495.525408           2                0.483696  ...
#
#    feature_Turbulence_In_gforces+Adverse_Weather_Metric  \
# 0                                           0.458651
# 1                                           0.253618
# 2                                           0.340985
# 3                                           0.621765
# 4                                           0.796924
#
#    feature_Cabin_Temperature-Max_Elevation  \
# 0                            -37871.404386
# 1                            -30116.205567
# 2                            -17485.965484
# 3                            -40128.326341
# 4                            -35416.305408
#
#    feature_Cabin_Temperature+Max_Elevation  \
# 0                             38028.044386
# 1                             30273.405567
# 2                             17659.885484
# 3                             40290.046341
# 4                             35574.745408
#
#    feature_Cabin_Temperature-Adverse_Weather_Metric  \
# 0                                         78.250308
# 1                                         78.597223
# 2                                         86.955684
# 3                                         80.660010
# 4                                         78.736304
#
#    feature_Cabin_Temperature+Adverse_Weather_Metric  \
# 0                                         78.389692
# 1                                         78.602777
# 2                                         86.964316
# 3                                         81.059990
# 4                                         79.703696
#
#    feature_Max_Elevation-Adverse_Weather_Metric  \
# 0                                  37949.654694
# 1                                  30194.802790
# 2                                  17572.921168
# 3                                  40208.986351
# 4                                  35495.041712
#
#    feature_Max_Elevation+Adverse_Weather_Metric  c_feat_1  c_feat_2  c_feat_3
# 0                                  37949.794079     False     False      True
# 1                                  30194.808345      True     False     False
# 2                                  17572.929800     False     False      True
# 3                                  40209.386332     False     False     False
# 4                                  35496.009103     False      True     False
#
# [5 rows x 133 columns]

# %%
df_test.shape
# Out:
# (2500, 133)

# %%
for i in df.columns:
    print(i)
    print(df[i].nunique())
# Out:
# Safety_Score
# 1175
# Days_Since_Inspection
# 23
# Total_Safety_Complaints
# 44
# Control_Metric
# 952
# Turbulence_In_gforces
# 1117
# Cabin_Temperature
# 950
# Accident_Type_Code
# 7
# Max_Elevation
# 4191
# Violations
# 6
# Adverse_Weather_Metric
# 4258
# feature_Violations_Safety_Score_mean
# 6
# feature_Violations_Safety_Score_max
# 5
# feature_Violations_Safety_Score_min
# 4
# feature_Violations_Safety_Score_std
# 6
# feature_Violations_Days_Since_Inspection_mean
# 6
# feature_Violations_Days_Since_Inspection_max
# 2
# feature_Violations_Days_Since_Inspection_min
# 4
# feature_Violations_Days_Since_Inspection_std
# 6
# feature_Violations_Total_Safety_Complaints_mean
# 6
# feature_Violations_Total_Safety_Complaints_max
# 3
# feature_Violations_Total_Safety_Complaints_min
# 1
# feature_Violations_Total_Safety_Complaints_std
# 6
# feature_Violations_Control_Metric_mean
# 6
# feature_Violations_Control_Metric_max
# 4
# feature_Violations_Control_Metric_min
# 4
# feature_Violations_Control_Metric_std
# 6
# feature_Violations_Turbulence_In_gforces_mean
# 6
# feature_Violations_Turbulence_In_gforces_max
# 4
# feature_Violations_Turbulence_In_gforces_min
# 3
# feature_Violations_Turbulence_In_gforces_std
# 6
# feature_Violations_Cabin_Temperature_mean
# 6
# feature_Violations_Cabin_Temperature_max
# 6
# feature_Violations_Cabin_Temperature_min
# 3
# feature_Violations_Cabin_Temperature_std
# 6
# feature_Violations_Max_Elevation_mean
# 6
# feature_Violations_Max_Elevation_max
# 4
# feature_Violations_Max_Elevation_min
# 3
# feature_Violations_Max_Elevation_std
# 6
# feature_Violations_Adverse_Weather_Metric_mean
# 6
# feature_Violations_Adverse_Weather_Metric_max
# 5
# feature_Violations_Adverse_Weather_Metric_min
# 6
# feature_Violations_Adverse_Weather_Metric_std
# 6
# feature_Accident_Type_Code_Safety_Score_mean
# 7
# feature_Accident_Type_Code_Safety_Score_max
# 3
# feature_Accident_Type_Code_Safety_Score_min
# 4
# feature_Accident_Type_Code_Safety_Score_std
# 7
# feature_Accident_Type_Code_Days_Since_Inspection_mean
# 7
# feature_Accident_Type_Code_Days_Since_Inspection_max
# 3
# feature_Accident_Type_Code_Days_Since_Inspection_min
# 3
# feature_Accident_Type_Code_Days_Since_Inspection_std
# 7
# feature_Accident_Type_Code_Total_Safety_Complaints_mean
# 7
# feature_Accident_Type_Code_Total_Safety_Complaints_max
# 3
# feature_Accident_Type_Code_Total_Safety_Complaints_min
# 1
# feature_Accident_Type_Code_Total_Safety_Complaints_std
# 7
# feature_Accident_Type_Code_Control_Metric_mean
# 7
# feature_Accident_Type_Code_Control_Metric_max
# 3
# feature_Accident_Type_Code_Control_Metric_min
# 5
# feature_Accident_Type_Code_Control_Metric_std
# 7
# feature_Accident_Type_Code_Turbulence_In_gforces_mean
# 7
# feature_Accident_Type_Code_Turbulence_In_gforces_max
# 5
# feature_Accident_Type_Code_Turbulence_In_gforces_min
# 3
# feature_Accident_Type_Code_Turbulence_In_gforces_std
# 7
# feature_Accident_Type_Code_Cabin_Temperature_mean
# 7
# feature_Accident_Type_Code_Cabin_Temperature_max
# 5
# feature_Accident_Type_Code_Cabin_Temperature_min
# 2
# feature_Accident_Type_Code_Cabin_Temperature_std
# 7
# feature_Accident_Type_Code_Max_Elevation_mean
# 7
# feature_Accident_Type_Code_Max_Elevation_max
# 6
# feature_Accident_Type_Code_Max_Elevation_min
# 4
# feature_Accident_Type_Code_Max_Elevation_std
# 7
# feature_Accident_Type_Code_Adverse_Weather_Metric_mean
# 7
# feature_Accident_Type_Code_Adverse_Weather_Metric_max
# 7
# feature_Accident_Type_Code_Adverse_Weather_Metric_min
# 7
# feature_Accident_Type_Code_Adverse_Weather_Metric_std
# 7
# feature_Safety_Score-Days_Since_Inspection
# 2451
# feature_Safety_Score+Days_Since_Inspection
# 2348
# feature_Safety_Score-Total_Safety_Complaints
# 5352
# feature_Safety_Score+Total_Safety_Complaints
# 5332
# feature_Safety_Score-Control_Metric
# 8664
# feature_Safety_Score+Control_Metric
# 8664
# feature_Safety_Score-Turbulence_In_gforces
# 9693
# feature_Safety_Score+Turbulence_In_gforces
# 9693
# feature_Safety_Score-Cabin_Temperature
# 9585
# feature_Safety_Score+Cabin_Temperature
# 9585
# feature_Safety_Score-Max_Elevation
# 9855
# feature_Safety_Score+Max_Elevation
# 9855
# feature_Safety_Score-Adverse_Weather_Metric
# 9979
# feature_Safety_Score+Adverse_Weather_Metric
# 9979
# feature_Days_Since_Inspection-Total_Safety_Complaints
# 60
# feature_Days_Since_Inspection+Total_Safety_Complaints
# 59
# feature_Days_Since_Inspection-Control_Metric
# 4168
# feature_Days_Since_Inspection+Control_Metric
# 4168
# feature_Days_Since_Inspection-Turbulence_In_gforces
# 5964
# feature_Days_Since_Inspection+Turbulence_In_gforces
# 5964
# feature_Days_Since_Inspection-Cabin_Temperature
# 1910
# feature_Days_Since_Inspection+Cabin_Temperature
# 1870
# feature_Days_Since_Inspection-Max_Elevation
# 8268
# feature_Days_Since_Inspection+Max_Elevation
# 8268
# feature_Days_Since_Inspection-Adverse_Weather_Metric
# 9166
# feature_Days_Since_Inspection+Adverse_Weather_Metric
# 9166
# feature_Total_Safety_Complaints-Control_Metric
# 5764
# feature_Total_Safety_Complaints+Control_Metric
# 5764
# feature_Total_Safety_Complaints-Turbulence_In_gforces
# 6496
# feature_Total_Safety_Complaints+Turbulence_In_gforces
# 6496
# feature_Total_Safety_Complaints-Cabin_Temperature
# 2668
# feature_Total_Safety_Complaints+Cabin_Temperature
# 2576
# feature_Total_Safety_Complaints-Max_Elevation
# 8389
# feature_Total_Safety_Complaints+Max_Elevation
# 8389
# feature_Total_Safety_Complaints-Adverse_Weather_Metric
# 9292
# feature_Total_Safety_Complaints+Adverse_Weather_Metric
# 9292
# feature_Control_Metric-Turbulence_In_gforces
# 8195
# feature_Control_Metric+Turbulence_In_gforces
# 8195
# feature_Control_Metric-Cabin_Temperature
# 9309
# feature_Control_Metric+Cabin_Temperature
# 9309
# feature_Control_Metric-Max_Elevation
# 9650
# feature_Control_Metric+Max_Elevation
# 9650
# feature_Control_Metric-Adverse_Weather_Metric
# 9968
# feature_Control_Metric+Adverse_Weather_Metric
# 9968
# feature_Turbulence_In_gforces-Cabin_Temperature
# 9586
# feature_Turbulence_In_gforces+Cabin_Temperature
# 9586
# feature_Turbulence_In_gforces-Max_Elevation
# 9759
# feature_Turbulence_In_gforces+Max_Elevation
# 9759
# feature_Turbulence_In_gforces-Adverse_Weather_Metric
# 9974
# feature_Turbulence_In_gforces+Adverse_Weather_Metric
# 9974
# feature_Cabin_Temperature-Max_Elevation
# 9797
# feature_Cabin_Temperature+Max_Elevation
# 9797
# feature_Cabin_Temperature-Adverse_Weather_Metric
# 9972
# feature_Cabin_Temperature+Adverse_Weather_Metric
# 9972
# feature_Max_Elevation-Adverse_Weather_Metric
# 9618
# feature_Max_Elevation+Adverse_Weather_Metric
# 9618
# c_feat_1
# 2
# c_feat_2
# 2
# c_feat_3
# 2

# %%
combined = pd.concat([df,df_test],axis =0)

# %%
combined["Violations"] = combined["Violations"].astype("category")
combined["Accident_Type_Code"] = combined["Accident_Type_Code"].astype("category")

# %%
combined.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0     49.223744                     14                       22
# 1     62.465753                     10                       27
# 2     63.059361                     13                       16
# 3     48.082192                     11                        9
# 4     26.484018                     13                       25
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       71.285324               0.272118              78.04
# 1       72.288058               0.423939              84.54
# 2       66.362808               0.322604              78.86
# 3       74.703737               0.337029              81.79
# 4       47.948952               0.541140              77.16
#
#   Accident_Type_Code  Max_Elevation Violations  Adverse_Weather_Metric  ...  \
# 0                  2   31335.476824          3                0.424352  ...
# 1                  2   26024.711057          2                0.352350  ...
# 2                  7   39269.053927          3                0.003364  ...
# 3                  3   42771.499200          1                0.211728  ...
# 4                  3   35509.228515          2                0.176883  ...
#
#    feature_Turbulence_In_gforces+Adverse_Weather_Metric  \
# 0                                           0.696470
# 1                                           0.776289
# 2                                           0.325968
# 3                                           0.548757
# 4                                           0.718024
#
#    feature_Cabin_Temperature-Max_Elevation  \
# 0                            -31257.436824
# 1                            -25940.171057
# 2                            -39190.193927
# 3                            -42689.709200
# 4                            -35432.068515
#
#    feature_Cabin_Temperature+Max_Elevation  \
# 0                             31413.516824
# 1                             26109.251057
# 2                             39347.913927
# 3                             42853.289200
# 4                             35586.388515
#
#    feature_Cabin_Temperature-Adverse_Weather_Metric  \
# 0                                         77.615648
# 1                                         84.187650
# 2                                         78.856636
# 3                                         81.578272
# 4                                         76.983117
#
#    feature_Cabin_Temperature+Adverse_Weather_Metric  \
# 0                                         78.464352
# 1                                         84.892350
# 2                                         78.863364
# 3                                         82.001728
# 4                                         77.336883
#
#    feature_Max_Elevation-Adverse_Weather_Metric  \
# 0                                  31335.052472
# 1                                  26024.358707
# 2                                  39269.050563
# 3                                  42771.287472
# 4                                  35509.051632
#
#    feature_Max_Elevation+Adverse_Weather_Metric  c_feat_1  c_feat_2  c_feat_3
# 0                                  31335.901176      True      True     False
# 1                                  26025.063407      True      True     False
# 2                                  39269.057291      True     False     False
# 3                                  42771.710929      True     False     False
# 4                                  35509.405399      True     False     False
#
# [5 rows x 133 columns]

# %%
combined.shape
# Out:
# (12500, 133)

# %%
df = combined.iloc[:10000,:]
df_test = combined.iloc[10000:,:]

# %%
# for KNN we need to standardize the data.
combined["Violations"] = combined["Violations"].astype("category")
combined["Accident_Type_Code"] = combined["Accident_Type_Code"].astype("category")

# %%
combined_dummy = pd.get_dummies(combined)

# %%
dum_df = combined_dummy.iloc[:df.shape[0],:]
dum_df_test = combined_dummy.iloc[df.shape[0]:,:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(dum_df)
normal = scaler.transform(dum_df)
normal_test = scaler.transform(dum_df_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import StratifiedKFold,KFold

# %%
from hyperopt import hp, tpe, fmin
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,precision_score,recall_score
from sklearn.model_selection import train_test_split

# %%
fixed_param_knn = {
              }

# %%
space_knn = {
             'n_neighbors': hp.uniform('n_neighbors',3,1000)
            }

# %%
def convert2(x):
    sample = []
    for i in x:
        if i=="Minor_Damage_And_Injuries":
            sample.append(1)
        if i=="Significant_Damage_And_Serious_Injuries":
            sample.append(3)
        if i=="Significant_Damage_And_Fatalities":
            sample.append(2)
        if i=="Highly_Fatal_And_Damaging":
            sample.append(0)
    return sample

# %%
from sklearn.metrics import log_loss
def convert(predict):
    out = []
    output = []
    for i in range(len(predict)):
        temp = max(predict[i])
        for j in range(4):
            if temp == predict[i][j]:
                out.append(j)
    for i in out:
        if i==0:
            output.append("Highly_Fatal_And_Damaging")
        if i==1:
            output.append("Minor_Damage_And_Injuries")
        if i==2:
            output.append("Significant_Damage_And_Fatalities")
        if i==3:
            output.append("Significant_Damage_And_Serious_Injuries")
    return output

# %%
#y_c = convert2(y_train.values)
#y_c_t = convert2(y_test.values)

# %%
'''
def objective_knn(params):
    cv = StratifiedKFold(4, random_state=42,shuffle = True)
    li = []
    for train, test in cv.split(normal,y):
        X_train, X_test = normal[train], normal[test]
        y_train, y_test = y.values[train], y.values[test]
        y_c = convert2(y_train)
        y_c_t = convert2(y_test)
        knn = KNeighborsClassifier(n_neighbors = int(params["n_neighbors"]),n_jobs = -1)
        knn.fit(X_train,y_c)
        temp = knn.predict(X_test)
        li.append(f1_score(y_c_t,temp,average = "weighted"))
    output = (sum(li)/4)
    print(output)
    return -1*output
'''
# Out:
# '\ndef objective_knn(params):\n    cv = StratifiedKFold(4, random_state=42,shuffle = True)\n    li = []\n    for train, test in cv.split(normal,y):\n        X_train, X_test = normal[train], normal[test]\n        y_train, y_test = y.values[train], y.values[test]\n        y_c = convert2(y_train)\n        y_c_t = convert2(y_test)\n        knn = KNeighborsClassifier(n_neighbors = int(params["n_neighbors"]),n_jobs = -1)\n        knn.fit(X_train,y_c)\n        temp = knn.predict(X_test)\n        li.append(f1_score(y_c_t,temp,average = "weighted"))\n    output = (sum(li)/4)\n    print(output)\n    return -1*output\n'

# %%
'''
best_gbm = fmin(objective_knn,
    space=space_knn,
    algo=tpe.suggest,
    max_evals=50)
    '''
# Out:
# '\nbest_gbm = fmin(objective_knn,\n    space=space_knn,\n    algo=tpe.suggest,\n    max_evals=50)\n    '

# %%
def convert3(x):
    sample = []
    for i in x:
        if i==1:
            sample.append("Minor_Damage_And_Injuries")
        if i==3:
            sample.append("Significant_Damage_And_Serious_Injuries")
        if i==2:
            sample.append("Significant_Damage_And_Fatalities")
        if i==0:
            sample.append("Highly_Fatal_And_Damaging")
    return sample

# %%
y_c = convert2(y.values)

# %%
# BEST KNN Hyperparameters

knn = KNeighborsClassifier(n_neighbors = 5,n_jobs = -1)
knn.fit(normal,y_c)
temp = knn.predict(normal_test)
temp1 = knn.predict(normal)

# %%
temp
# Out:
# array([0, 1, 3, ..., 3, 3, 0])

# %%
test_pred = convert3(temp)
temp = pd.DataFrame(test_pred)
temp.to_csv(r"E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident\Stacknet/KNN_feature_1_test.csv",index = False)

# %%
train_pred = convert3(temp1)
temp2 = pd.DataFrame(train_pred)
temp2.to_csv(r"E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident\Stacknet/KNN_feature_1_train.csv",index = False)

# %%
submission = pd.DataFrame()
submission["Accident_ID"] = ID
submission["Severity"] = test_pred
submission.to_csv("E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident/submission.csv",index = False)

# %%
submission.head()
# Out:
#    Accident_ID                                 Severity
# 0            1                Highly_Fatal_And_Damaging
# 1           10                Minor_Damage_And_Injuries
# 2           14  Significant_Damage_And_Serious_Injuries
# 3           17                Highly_Fatal_And_Damaging
# 4           21                Highly_Fatal_And_Damaging

# %%
from sklearn.naive_bayes import GaussianNB

# %%
cv = StratifiedKFold(4, random_state=42,shuffle = True)
li = []
for train, test in cv.split(df,y):
    X_train, X_test = df.iloc[train,:], df.iloc[test,:]
    y_train, y_test = y.values[train], y.values[test]
    #y_c = convert2(y_train)
    y_c_t = convert2(y_test)
    gnb = GaussianNB()
    gnb.fit(X_train,y_train)
    temp = gnb.predict(X_test)
    li.append(f1_score(y_c_t,convert2(temp),average = "weighted"))
    output = (sum(li)/4)
print(li)
print(output)
# Out:
# C:\Users\ishtd\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ishtd\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0.5598376701528074, 0.5548260525289134, 0.5616717871617306, 0.559713323728529]
# 0.5590122083929951
# C:\Users\ishtd\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ishtd\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
gnb = GaussianNB()
gnb.fit(df.values,y.values)
gnb_pred= gnb.predict(df_test)
temp = pd.DataFrame()
temp["GNB"] = gnb_pred
temp.to_csv("E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident\Stacknet/gnb_feature_1_test.csv",index = False)

train_pred =gnb.predict(df)
temp = pd.DataFrame()
temp["GNB"] = train_pred
temp.to_csv("E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident\Stacknet/gnb_feature_1_train.csv",index = False)
# Out:
# C:\Users\ishtd\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
submission = pd.DataFrame()
submission["Accident_ID"] = ID
submission["Severity"] = temp
submission.to_csv("E:\Data Science\Kaggle Competitions dataset\Hackerearth Airplane Accident/submission.csv",index = False)
